# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
# <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# ## GenAI 01 Common Applications with LLM

# %%
# Import necessary libraries
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Import necessary libraries
#       2 from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
# ----> 3 from datasets import load_dataset
#       4 import pandas as pd
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\__init__.py:43
#      40 del pyarrow
#      41 del version
# ---> 43 from .arrow_dataset import Dataset
#      44 from .arrow_reader import ReadInstruction
#      45 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:66
#      64 from . import config
#      65 from .arrow_reader import ArrowReader
# ---> 66 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      67 from .download.download_config import DownloadConfig
#      68 from .download.streaming_download_manager import xgetsize
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\arrow_writer.py:27
#      24 import pyarrow.parquet as pq
#      26 from . import config
# ---> 27 from .features import Features, Image, Value
#      28 from .features.features import (
#      29     FeatureType,
#      30     _ArrayXDExtensionType,
#    (...)
#      36     to_pyarrow_listarray,
#      37 )
#      38 from .filesystems import is_remote_filesystem
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\features\__init__.py:17
#       1 # flake8: noqa
#       3 __all__ = [
#       4     "Audio",
#       5     "Array2D",
#    (...)
#      15     "TranslationVariableLanguages",
#      16 ]
# ---> 17 from .audio import Audio
#      18 from .features import Array2D, Array3D, Array4D, Array5D, ClassLabel, Features, Sequence, Value
#      19 from .image import Image
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\features\audio.py:10
#       7 import pyarrow as pa
#       9 from .. import config
# ---> 10 from ..download.streaming_download_manager import xopen, xsplitext
#      11 from ..table import array_cast
#      12 from ..utils.py_utils import no_op_if_value_is_null, string_to_dict
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\download\__init__.py:10
#       8 from .download_config import DownloadConfig
#       9 from .download_manager import DownloadManager, DownloadMode
# ---> 10 from .streaming_download_manager import StreamingDownloadManager
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\download\streaming_download_manager.py:21
#      18 from aiohttp.client_exceptions import ClientError
#      20 from .. import config
# ---> 21 from ..filesystems import COMPRESSION_FILESYSTEMS
#      22 from ..utils.file_utils import (
#      23     get_authentication_headers_for_url,
#      24     http_head,
#    (...)
#      28     url_or_path_join,
#      29 )
#      30 from ..utils.logging import get_logger
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\filesystems\__init__.py:16
#      13 _has_s3fs = importlib.util.find_spec("s3fs") is not None
#      15 if _has_s3fs:
# ---> 16     from .s3filesystem import S3FileSystem  # noqa: F401
#      18 COMPRESSION_FILESYSTEMS: List[compression.BaseCompressedFileFileSystem] = [
#      19     compression.Bz2FileSystem,
#      20     compression.GzipFileSystem,
#    (...)
#      23     compression.ZstdFileSystem,
#      24 ]
#      26 # Register custom filesystems
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\datasets\filesystems\s3filesystem.py:1
# ----> 1 import s3fs
#       4 class S3FileSystem(s3fs.S3FileSystem):
#       5     """
#       6     `datasets.filesystems.S3FileSystem` is a subclass of [`s3fs.S3FileSystem`](https://s3fs.readthedocs.io/en/latest/api.html).
#       7
#    (...)
#     112     ```
#     113     """
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\s3fs\__init__.py:1
# ----> 1 from .core import S3FileSystem, S3File
#       2 from .mapping import S3Map
#       4 from ._version import get_versions
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\s3fs\core.py:29
#      27 import aiobotocore
#      28 import botocore
# ---> 29 import aiobotocore.session
#      30 from aiobotocore.config import AioConfig
#      31 from botocore.exceptions import ClientError, HTTPClientError, ParamValidationError
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\aiobotocore\session.py:1
# ----> 1 from botocore import UNSIGNED, translate
#       2 from botocore.exceptions import PartialCredentialsError
#       3 from botocore.session import (
#       4     EVENT_ALIASES,
#       5     ServiceModel,
#    (...)
#       8     copy,
#       9 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\botocore\translate.py:16
#       1 # Copyright (c) 2012-2013 Mitch Garnaat http://garnaat.org/
#       2 # Copyright 2012-2016 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       3 #
#    (...)
#      12 # ANY KIND, either express or implied. See the License for the specific
#      13 # language governing permissions and limitations under the License.
#      14 import copy
# ---> 16 from botocore.utils import merge_dicts
#      19 def build_retry_config(
#      20     endpoint_prefix, retry_model, definitions, client_retry_config=None
#      21 ):
#      22     service_config = retry_model.get(endpoint_prefix, {})
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\botocore\utils.py:37
#      35 import botocore
#      36 import botocore.awsrequest
# ---> 37 import botocore.httpsession
#      39 # IP Regexes retained for backwards compatibility
#      40 from botocore.compat import HEX_PAT  # noqa: F401
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\botocore\httpsession.py:22
#      20 from urllib3.exceptions import SSLError as URLLib3SSLError
#      21 from urllib3.util.retry import Retry
# ---> 22 from urllib3.util.ssl_ import (
#      23     DEFAULT_CIPHERS,
#      24     OP_NO_COMPRESSION,
#      25     PROTOCOL_TLS,
#      26     OP_NO_SSLv2,
#      27     OP_NO_SSLv3,
#      28     is_ipaddress,
#      29     ssl,
#      30 )
#      31 from urllib3.util.url import parse_url
#      33 try:
#
# ImportError: cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\U723303\AppData\Local\anaconda3\Lib\site-packages\urllib3\util\ssl_.py)
